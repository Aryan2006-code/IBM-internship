# %%
import pandas as pd
print("done")
# Out:
# done

# %%
# pandas has 2 core object : series , data frame
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#series

pd.Series((1,2,3,4),name = "age")
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: age, dtype: int64

# %%
# dataframe
#dict

di ={"name": ["aryan","mango" ,"ball", "pen"] , 
     "identity":["human","fruit", "sports","stationary"]}

df =pd.DataFrame(di)

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df.head(2)
# Out:
#     name identity
# 0  aryan    human
# 1  mango    fruit

# %%
df.tail(2)
# Out:
#    name    identity
# 2  ball      sports
# 3   pen  stationary

# %%
df.sample(2)
# Out:
#    name    identity
# 3   pen  stationary
# 2  ball      sports

# %%
df.head()
# Out:
#     name    identity
# 0  aryan       human
# 1  mango       fruit
# 2   ball      sports
# 3    pen  stationary

# %%
type(df["name"])
# Out:
# pandas.Series

# %%
df[["name" ,"identity"]]
# Out:
#     name    identity
# 0  aryan       human
# 1  mango       fruit
# 2   ball      sports
# 3    pen  stationary

# %%
#add some col
count=[2,5,1,6]
df.insert(0,"count",count)

# %%
df
# Out:
#    count   name    identity
# 0      2  aryan       human
# 1      5  mango       fruit
# 2      1   ball      sports
# 3      6    pen  stationary

# %%
brand =("god","mazza","vp15" ,"retro")
# df.insert(3,"brand",brand)
df
# Out:
#    count   name    identity  brand
# 0      2  aryan       human    god
# 1      5  mango       fruit  mazza
# 2      1   ball      sports   vp15
# 3      6    pen  stationary  retro

# %%
df["id"] =[1,2,3,4]

# %%
df.sample()
# Out:
#    count   name identity brand  id
# 0      2  aryan    human   god   1

# %%
#new df2, id , weight 

df2 = pd.DataFrame({"id":[1,2,3,4,5],"weight":[23,45,67,78,None]})
df2
# Out:
#    id  weight
# 0   1    23.0
# 1   2    45.0
# 2   3    67.0
# 3   4    78.0
# 4   5     NaN

# %%
#merge or join

pd.merge(df,df2 , how="right",on="id")
# Out:
#    count   name    identity  brand  id  weight
# 0    2.0  aryan       human    god   1    23.0
# 1    5.0  mango       fruit  mazza   2    45.0
# 2    1.0   ball      sports   vp15   3    67.0
# 3    6.0    pen  stationary  retro   4    78.0
# 4    NaN    NaN         NaN    NaN   5     NaN
